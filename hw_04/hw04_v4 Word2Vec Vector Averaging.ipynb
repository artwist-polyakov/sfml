# %% [markdown]
# ### Состав команды:
#
# - Поляков Александр (Aleksandr Polyakov)
# - Востриков Алексей (Alexey Vostrikoff)
# - Садыков Динар (Dinar_Sadykow)
# - Федотов Андрей (Andrei Fedotov)
# - Каштанкина Ксения
# - Овчинников Алексей (Aleksey)
# - Пьянков Алексей
# - Лукошко Роберт (Robert)
# - Поперечный Богдан (Bogdan2105)

# %% [markdown]
# ### Описание данных
#
# * train.csv - данные для обучения
# * test.csv - данные для подготовки самбита и проверки
# * sampleSubmission.csv - пример корректного но бесполезного сабмита
# * other.csv - необязательные данные для доп.статистик и прочих извращений (например обучение word2vec-а)
#
# ### Описание полей
#
# * id - внутренний идетификатор
# * name - название вакансии
# * description - текст вакансии
# * target - класс заинтересованности

# %%
# Устанавливаем библиотеку для word2vec
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages (3.5.0)
# Requirement already satisfied: numpy>=1.11.3 in /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages (from gensim) (1.14.3)
# Requirement already satisfied: scipy>=0.18.1 in /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages (from gensim) (1.1.0)
# Requirement already satisfied: six>=1.5.0 in /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages (from gensim) (1.11.0)
# Requirement already satisfied: smart-open>=1.2.1 in /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages (from gensim) (1.6.0)
# Requirement already satisfied: boto>=2.32 in /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages (from smart-open>=1.2.1->gensim) (2.48.0)
# Requirement already satisfied: boto3 in /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages (from smart-open>=1.2.1->gensim) (1.8.8)
# Requirement already satisfied: requests in /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages (from smart-open>=1.2.1->gensim) (2.19.1)
# Requirement already satisfied: bz2file in /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages (from smart-open>=1.2.1->gensim) (0.98)
# Requirement already satisfied: botocore<1.12.0,>=1.11.8 in /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages (from boto3->smart-open>=1.2.1->gensim) (1.11.8)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages (from boto3->smart-open>=1.2.1->gensim) (0.9.3)
# Requirement already satisfied: s3transfer<0.2.0,>=0.1.10 in /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages (from boto3->smart-open>=1.2.1->gensim) (0.1.13)
# Requirement already satisfied: urllib3<1.24,>=1.21.1 in /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages (from requests->smart-open>=1.2.1->gensim) (1.22)
# Requirement already satisfied: idna<2.8,>=2.5 in /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages (from requests->smart-open>=1.2.1->gensim) (2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages (from requests->smart-open>=1.2.1->gensim) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages (from requests->smart-open>=1.2.1->gensim) (2018.4.16)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1; python_version >= "2.7" in /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages (from botocore<1.12.0,>=1.11.8->boto3->smart-open>=1.2.1->gensim) (2.7.3)
# Requirement already satisfied: docutils>=0.10 in /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages (from botocore<1.12.0,>=1.11.8->boto3->smart-open>=1.2.1->gensim) (0.14)

# %%
# !pip install cython
# Out:
# Requirement already satisfied: cython in /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages (0.28.2)

# %% [markdown]
# # Шаг 1. Загрузим файлы other.csv, train.cvs и test.csv
# Файл other.csv содержит дополнительные неразмеченные данные, которые можно использовать для анализа.

# %%
# %%time
import pandas as pd
other_df = pd.read_csv('other.csv','\t')
print('Я загрузила {} неразмеченных описания для обучения word2vec'.format(other_df['description'].size))
train_df = pd.read_csv('train.csv','\t')
print('Я загрузила {} размеченных тренировочных описаний'.format(train_df['description'].size))
test_df = pd.read_csv('test.csv','\t')
print('Я загрузила {} неразмеченных тестовых описаний'.format(test_df['description'].size))
# Out:
# Я загрузила 594534 неразмеченных описания для обучения word2vec
# Я загрузила 200000 размеченных тренировочных описаний
# Я загрузила 170179 неразмеченных тестовых описаний
# CPU times: user 17.3 s, sys: 1.8 s, total: 19.1 s
# Wall time: 19.2 s

# %% [markdown]
# # Шаг 2. Запишем функцию перекомпоновки описаний в лист слов

# %%
from bs4 import BeautifulSoup
import re
from nltk.corpus import stopwords

def vac_to_wordlist(description, remove_stopwords = False):
    """
    берёт описание и превращает его в набор слов
    есть триггер включения выключения учета стоп-слов
    """
    #превращаем дескрипшен из хтмл в текст
    vac_text = BeautifulSoup(description, 'html5lib').get_text()
    
    #удаляем всё что не буквы
    vac_text = re.sub('[^а-яА-Яa-zA-Z]', ' ', vac_text)
    
    #превращаем текст в слова и переводим в нижний регистр
    words = vac_text.lower().split() 
    
    #опционально удаляем минус-слова
    if remove_stopwords:
        stops = set(stopwords.words('russian'))
        words = [w for w in words if not w in stops]
    return words

# %%
clean_vac = vac_to_wordlist( train_df['description'][0] , remove_stopwords = False)
clean_vac
# Out:
# ['в',
#  'новый',
#  'магазин',
#  'york',
#  'хозтовары',
#  'приглашаем',
#  'на',
#  'постоянную',
#  'работу',
#  'руководителя',
#  'секции',
#  'хозтовары',
#  'обязанности',
#  'организация',
#  'эффективного',
#  'и',
#  'культурного',
#  'обслуживания',
#  'покупателей',
#  'организация',
#  'приемки',
#  'сдачи',
#  'товаров',
#  'на',
#  'склад',
#  'консультация',
#  'покупателей',
#  'по',
#  'вопросам',
#  'касающимся',
#  'оказываемых',
#  'услуг',
#  'контроль',
#  'своевременной',
#  'подачи',
#  'товаров',
#  'в',
#  'торговую',
#  'секцию',
#  'проверка',
#  'качества',
#  'сроков',
#  'годности',
#  'тмц',
#  'наличие',
#  'маркировок',
#  'ценников',
#  'на',
#  'товарах',
#  'организация',
#  'бесперебойной',
#  'работы',
#  'товарной',
#  'секции',
#  'и',
#  'участка',
#  'склада',
#  'закрепленного',
#  'за',
#  'ней',
#  'контроль',
#  'за',
#  'сохранностью',
#  'товаров',
#  'торгового',
#  'оборудования',
#  'и',
#  'прочих',
#  'материальных',
#  'ценностей',
#  'инвентаризация',
#  'товаров',
#  'требования',
#  'знание',
#  'товарной',
#  'группы',
#  'знание',
#  'правил',
#  'приемки',
#  'товара',
#  'опыт',
#  'работы',
#  'в',
#  'розничной',
#  'торговле',
#  'в',
#  'качестве',
#  'продавца',
#  'р',
#  'заместителя',
#  'заведующего',
#  'секцией',
#  'отделом',
#  'ответственность',
#  'лидерские',
#  'качества',
#  'опыт',
#  'управления',
#  'коллективом',
#  'условия',
#  'новый',
#  'современный',
#  'магазин',
#  'розничной',
#  'торговли',
#  'хозтоварами',
#  'хороший',
#  'коллектив',
#  'достойная',
#  'зарплата',
#  'премии',
#  'соц',
#  'пакет',
#  'график',
#  'работы',
#  'пн',
#  'пт',
#  'с',
#  'до',
#  'плавающий',
#  'место',
#  'работы',
#  'ул',
#  'никифорова',
#  'уручье']

# %% [markdown]
# # Шаг 3. Пишем функцию, которая будет разделять описания на предложения
#
# Word2Vec хочет работать с отдельными предложениями, а не с целыми описаниями

# %%
import nltk.data
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# %%
import nltk.data
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
def description_to_sentences( description, tokenizer, remove_stopwords=False ):
    """
    Функция, которая разделяет текст на предложения
    """
    
    all_sentences = tokenizer.tokenize(description.strip())
    
    # проходим в цикле по всем предложениям
    sentences = []
    for sentence in all_sentences:
        # Если предложение пустое, то пропускаем его
        if len(sentence) > 0:
            # Иначе длбавляем описание в лист разделённое пословно
            sentences.append( vac_to_wordlist( sentence, remove_stopwords ))
    return sentences

# %%
clean_vac = description_to_sentences( train_df['description'][0] , tokenizer, remove_stopwords = False)
clean_vac
# Out:
# [['в',
#   'новый',
#   'магазин',
#   'york',
#   'хозтовары',
#   'приглашаем',
#   'на',
#   'постоянную',
#   'работу',
#   'руководителя',
#   'секции',
#   'хозтовары',
#   'обязанности',
#   'организация',
#   'эффективного',
#   'и',
#   'культурного',
#   'обслуживания',
#   'покупателей',
#   'организация',
#   'приемки',
#   'сдачи',
#   'товаров',
#   'на',
#   'склад',
#   'консультация',
#   'покупателей',
#   'по',
#   'вопросам',
#   'касающимся',
#   'оказываемых',
#   'услуг',
#   'контроль',
#   'своевременной',
#   'подачи',
#   'товаров',
#   'в',
#   'торговую',
#   'секцию',
#   'проверка',
#   'качества',
#   'сроков',
#   'годности',
#   'тмц',
#   'наличие',
#   'маркировок',
#   'ценников',
#   'на',
#   'товарах',
#   'организация',
#   'бесперебойной',
#   'работы',
#   'товарной',
#   'секции',
#   'и',
#   'участка',
#   'склада',
#   'закрепленного',
#   'за',
#   'ней',
#   'контроль',
#   'за',
#   'сохранностью',
#   'товаров',
#   'торгового',
#   'оборудования',
#   'и',
#   'прочих',
#   'материальных',
#   'ценностей',
#   'инвентаризация',
#   'товаров',
#   'требования',
#   'знание',
#   'товарной',
#   'группы',
#   'знание',
#   'правил',
#   'приемки',
#   'товара',
#   'опыт',
#   'работы',
#   'в',
#   'розничной',
#   'торговле',
#   'в',
#   'качестве',
#   'продавца',
#   'р'],
#  ['заместителя',
#   'заведующего',
#   'секцией',
#   'отделом',
#   'ответственность',
#   'лидерские',
#   'качества',
#   'опыт',
#   'управления',
#   'коллективом',
#   'условия',
#   'новый',
#   'современный',
#   'магазин',
#   'розничной',
#   'торговли',
#   'хозтоварами',
#   'хороший',
#   'коллектив',
#   'достойная',
#   'зарплата',
#   'премии',
#   'соц',
#   'пакет',
#   'график',
#   'работы',
#   'пн',
#   'пт',
#   'с',
#   'до',
#   'плавающий',
#   'место',
#   'работы',
#   'ул'],
#  ['никифорова', 'уручье']]

# %% [markdown]
# # Шаг 4. Соберём огромный "мешок предложений" из датасетов train и other

# %%
# %%time
sentences = []
print('Собираю отдельные предложения из тренировочного набора: {} описаний'.format(train_df['description'].size))
i = 0
for description in train_df['description']:
    i += 1
    if (i % 10000) == 0:
        print('Прошла {} из {} описаний ({:.1%})'.format(i, train_df['description'].size,i/train_df['description'].size))
    sentences += description_to_sentences(description, tokenizer) # плюс равно чтобы добавил все листы, а не только первый
print('Собираю отдельные предложения из остального неразмеченного набора: {} описаний'.format(other_df['description'].size))
i = 0
for description in other_df['description']:
    i += 1
    if (i % 10000) == 0:
        print('Прошла {} из {} описаний ({:.1%})'.format(i, other_df['description'].size,i/other_df['description'].size))
    sentences += description_to_sentences(description, tokenizer)
# Out:
# Собираю отдельные предложения из тренировочного набора: 200000 описаний
# /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:219: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# Прошла 2500 из 200000 описаний (1.2%)
# Прошла 5000 из 200000 описаний (2.5%)
# Прошла 7500 из 200000 описаний (3.8%)
# Прошла 10000 из 200000 описаний (5.0%)
# Прошла 12500 из 200000 описаний (6.2%)
# Прошла 15000 из 200000 описаний (7.5%)
# Прошла 17500 из 200000 описаний (8.8%)
# Прошла 20000 из 200000 описаний (10.0%)
# Прошла 22500 из 200000 описаний (11.2%)
# Прошла 25000 из 200000 описаний (12.5%)
# Прошла 27500 из 200000 описаний (13.8%)
# Прошла 30000 из 200000 описаний (15.0%)
# Прошла 32500 из 200000 описаний (16.2%)
# Прошла 35000 из 200000 описаний (17.5%)
# Прошла 37500 из 200000 описаний (18.8%)
# Прошла 40000 из 200000 описаний (20.0%)
# Прошла 42500 из 200000 описаний (21.2%)
# Прошла 45000 из 200000 описаний (22.5%)
# Прошла 47500 из 200000 описаний (23.8%)
# Прошла 50000 из 200000 описаний (25.0%)
# Прошла 52500 из 200000 описаний (26.2%)
# Прошла 55000 из 200000 описаний (27.5%)
# Прошла 57500 из 200000 описаний (28.7%)
# Прошла 60000 из 200000 описаний (30.0%)
# Прошла 62500 из 200000 описаний (31.2%)
# Прошла 65000 из 200000 описаний (32.5%)
# Прошла 67500 из 200000 описаний (33.8%)
# Прошла 70000 из 200000 описаний (35.0%)
# Прошла 72500 из 200000 описаний (36.2%)
# Прошла 75000 из 200000 описаний (37.5%)
# Прошла 77500 из 200000 описаний (38.8%)
# Прошла 80000 из 200000 описаний (40.0%)
# Прошла 82500 из 200000 описаний (41.2%)
# Прошла 85000 из 200000 описаний (42.5%)
# Прошла 87500 из 200000 описаний (43.8%)
# Прошла 90000 из 200000 описаний (45.0%)
# Прошла 92500 из 200000 описаний (46.2%)
# Прошла 95000 из 200000 описаний (47.5%)
# Прошла 97500 из 200000 описаний (48.8%)
# Прошла 100000 из 200000 описаний (50.0%)
# Прошла 102500 из 200000 описаний (51.2%)
# Прошла 105000 из 200000 описаний (52.5%)
# Прошла 107500 из 200000 описаний (53.8%)
# Прошла 110000 из 200000 описаний (55.0%)
# Прошла 112500 из 200000 описаний (56.2%)
# Прошла 115000 из 200000 описаний (57.5%)
# Прошла 117500 из 200000 описаний (58.8%)
# Прошла 120000 из 200000 описаний (60.0%)
# Прошла 122500 из 200000 описаний (61.3%)
# Прошла 125000 из 200000 описаний (62.5%)
# Прошла 127500 из 200000 описаний (63.7%)
# Прошла 130000 из 200000 описаний (65.0%)
# Прошла 132500 из 200000 описаний (66.2%)
# Прошла 135000 из 200000 описаний (67.5%)
# Прошла 137500 из 200000 описаний (68.8%)
# Прошла 140000 из 200000 описаний (70.0%)
# Прошла 142500 из 200000 описаний (71.2%)
# Прошла 145000 из 200000 описаний (72.5%)
# Прошла 147500 из 200000 описаний (73.8%)
# Прошла 150000 из 200000 описаний (75.0%)
# Прошла 152500 из 200000 описаний (76.2%)
# Прошла 155000 из 200000 описаний (77.5%)
# Прошла 157500 из 200000 описаний (78.8%)
# Прошла 160000 из 200000 описаний (80.0%)
# Прошла 162500 из 200000 описаний (81.2%)
# Прошла 165000 из 200000 описаний (82.5%)
# Прошла 167500 из 200000 описаний (83.8%)
# Прошла 170000 из 200000 описаний (85.0%)
# Прошла 172500 из 200000 описаний (86.2%)
# Прошла 175000 из 200000 описаний (87.5%)
# Прошла 177500 из 200000 описаний (88.8%)
# Прошла 180000 из 200000 описаний (90.0%)
# Прошла 182500 из 200000 описаний (91.2%)
# Прошла 185000 из 200000 описаний (92.5%)
# Прошла 187500 из 200000 описаний (93.8%)
# Прошла 190000 из 200000 описаний (95.0%)
# Прошла 192500 из 200000 описаний (96.2%)
# Прошла 195000 из 200000 описаний (97.5%)
# Прошла 197500 из 200000 описаний (98.8%)
# Прошла 200000 из 200000 описаний (100.0%)
# Собираю отдельные предложения из остального неразмеченного набора: 594534 описаний
# Прошла 2500 из 594534 описаний (0.4%)
# Прошла 5000 из 594534 описаний (0.8%)
# Прошла 7500 из 594534 описаний (1.3%)
# Прошла 10000 из 594534 описаний (1.7%)
# Прошла 12500 из 594534 описаний (2.1%)
# Прошла 15000 из 594534 описаний (2.5%)
# Прошла 17500 из 594534 описаний (2.9%)
# Прошла 20000 из 594534 описаний (3.4%)
# Прошла 22500 из 594534 описаний (3.8%)
# Прошла 25000 из 594534 описаний (4.2%)
# Прошла 27500 из 594534 описаний (4.6%)
# Прошла 30000 из 594534 описаний (5.0%)
# Прошла 32500 из 594534 описаний (5.5%)
# Прошла 35000 из 594534 описаний (5.9%)
# Прошла 37500 из 594534 описаний (6.3%)
# Прошла 40000 из 594534 описаний (6.7%)
# Прошла 42500 из 594534 описаний (7.1%)
# Прошла 45000 из 594534 описаний (7.6%)
# Прошла 47500 из 594534 описаний (8.0%)
# Прошла 50000 из 594534 описаний (8.4%)
# Прошла 52500 из 594534 описаний (8.8%)
# Прошла 55000 из 594534 описаний (9.3%)
# Прошла 57500 из 594534 описаний (9.7%)
# Прошла 60000 из 594534 описаний (10.1%)
# Прошла 62500 из 594534 описаний (10.5%)
# Прошла 65000 из 594534 описаний (10.9%)
# Прошла 67500 из 594534 описаний (11.4%)
# Прошла 70000 из 594534 описаний (11.8%)
# Прошла 72500 из 594534 описаний (12.2%)
# Прошла 75000 из 594534 описаний (12.6%)
# Прошла 77500 из 594534 описаний (13.0%)
# Прошла 80000 из 594534 описаний (13.5%)
# Прошла 82500 из 594534 описаний (13.9%)
# Прошла 85000 из 594534 описаний (14.3%)
# Прошла 87500 из 594534 описаний (14.7%)
# Прошла 90000 из 594534 описаний (15.1%)
# Прошла 92500 из 594534 описаний (15.6%)
# Прошла 95000 из 594534 описаний (16.0%)
# Прошла 97500 из 594534 описаний (16.4%)
# Прошла 100000 из 594534 описаний (16.8%)
# Прошла 102500 из 594534 описаний (17.2%)
# Прошла 105000 из 594534 описаний (17.7%)
# Прошла 107500 из 594534 описаний (18.1%)
# Прошла 110000 из 594534 описаний (18.5%)
# Прошла 112500 из 594534 описаний (18.9%)
# Прошла 115000 из 594534 описаний (19.3%)
# Прошла 117500 из 594534 описаний (19.8%)
# Прошла 120000 из 594534 описаний (20.2%)
# Прошла 122500 из 594534 описаний (20.6%)
# Прошла 125000 из 594534 описаний (21.0%)
# Прошла 127500 из 594534 описаний (21.4%)
# Прошла 130000 из 594534 описаний (21.9%)
# Прошла 132500 из 594534 описаний (22.3%)
# Прошла 135000 из 594534 описаний (22.7%)
# Прошла 137500 из 594534 описаний (23.1%)
# Прошла 140000 из 594534 описаний (23.5%)
# Прошла 142500 из 594534 описаний (24.0%)
# Прошла 145000 из 594534 описаний (24.4%)
# Прошла 147500 из 594534 описаний (24.8%)
# Прошла 150000 из 594534 описаний (25.2%)
# Прошла 152500 из 594534 описаний (25.7%)
# Прошла 155000 из 594534 описаний (26.1%)
# Прошла 157500 из 594534 описаний (26.5%)
# Прошла 160000 из 594534 описаний (26.9%)
# Прошла 162500 из 594534 описаний (27.3%)
# Прошла 165000 из 594534 описаний (27.8%)
# Прошла 167500 из 594534 описаний (28.2%)
# Прошла 170000 из 594534 описаний (28.6%)
# Прошла 172500 из 594534 описаний (29.0%)
# Прошла 175000 из 594534 описаний (29.4%)
# Прошла 177500 из 594534 описаний (29.9%)
# Прошла 180000 из 594534 описаний (30.3%)
# Прошла 182500 из 594534 описаний (30.7%)
# Прошла 185000 из 594534 описаний (31.1%)
# Прошла 187500 из 594534 описаний (31.5%)
# Прошла 190000 из 594534 описаний (32.0%)
# Прошла 192500 из 594534 описаний (32.4%)
# Прошла 195000 из 594534 описаний (32.8%)
# Прошла 197500 из 594534 описаний (33.2%)
# Прошла 200000 из 594534 описаний (33.6%)
# Прошла 202500 из 594534 описаний (34.1%)
# Прошла 205000 из 594534 описаний (34.5%)
# Прошла 207500 из 594534 описаний (34.9%)
# Прошла 210000 из 594534 описаний (35.3%)
# Прошла 212500 из 594534 описаний (35.7%)
# Прошла 215000 из 594534 описаний (36.2%)
# Прошла 217500 из 594534 описаний (36.6%)
# Прошла 220000 из 594534 описаний (37.0%)
# Прошла 222500 из 594534 описаний (37.4%)
# Прошла 225000 из 594534 описаний (37.8%)
# Прошла 227500 из 594534 описаний (38.3%)
# Прошла 230000 из 594534 описаний (38.7%)
# Прошла 232500 из 594534 описаний (39.1%)
# Прошла 235000 из 594534 описаний (39.5%)
# Прошла 237500 из 594534 описаний (39.9%)
# Прошла 240000 из 594534 описаний (40.4%)
# Прошла 242500 из 594534 описаний (40.8%)
# Прошла 245000 из 594534 описаний (41.2%)
# Прошла 247500 из 594534 описаний (41.6%)
# Прошла 250000 из 594534 описаний (42.0%)
# Прошла 252500 из 594534 описаний (42.5%)
# Прошла 255000 из 594534 описаний (42.9%)
# Прошла 257500 из 594534 описаний (43.3%)
# Прошла 260000 из 594534 описаний (43.7%)
# Прошла 262500 из 594534 описаний (44.2%)
# Прошла 265000 из 594534 описаний (44.6%)
# Прошла 267500 из 594534 описаний (45.0%)
# Прошла 270000 из 594534 описаний (45.4%)
# Прошла 272500 из 594534 описаний (45.8%)
# Прошла 275000 из 594534 описаний (46.3%)
# Прошла 277500 из 594534 описаний (46.7%)
# Прошла 280000 из 594534 описаний (47.1%)
# Прошла 282500 из 594534 описаний (47.5%)
# Прошла 285000 из 594534 описаний (47.9%)
# Прошла 287500 из 594534 описаний (48.4%)
# Прошла 290000 из 594534 описаний (48.8%)
# Прошла 292500 из 594534 описаний (49.2%)
# Прошла 295000 из 594534 описаний (49.6%)
# Прошла 297500 из 594534 описаний (50.0%)
# Прошла 300000 из 594534 описаний (50.5%)
# Прошла 302500 из 594534 описаний (50.9%)
# Прошла 305000 из 594534 описаний (51.3%)
# Прошла 307500 из 594534 описаний (51.7%)
# Прошла 310000 из 594534 описаний (52.1%)
# Прошла 312500 из 594534 описаний (52.6%)
# Прошла 315000 из 594534 описаний (53.0%)
# Прошла 317500 из 594534 описаний (53.4%)
# Прошла 320000 из 594534 описаний (53.8%)
# Прошла 322500 из 594534 описаний (54.2%)
# Прошла 325000 из 594534 описаний (54.7%)
# Прошла 327500 из 594534 описаний (55.1%)
# Прошла 330000 из 594534 описаний (55.5%)
# Прошла 332500 из 594534 описаний (55.9%)
# Прошла 335000 из 594534 описаний (56.3%)
# Прошла 337500 из 594534 описаний (56.8%)
# Прошла 340000 из 594534 описаний (57.2%)
# Прошла 342500 из 594534 описаний (57.6%)
# Прошла 345000 из 594534 описаний (58.0%)
# Прошла 347500 из 594534 описаний (58.4%)
# Прошла 350000 из 594534 описаний (58.9%)
# Прошла 352500 из 594534 описаний (59.3%)
# Прошла 355000 из 594534 описаний (59.7%)
# Прошла 357500 из 594534 описаний (60.1%)
# Прошла 360000 из 594534 описаний (60.6%)
# Прошла 362500 из 594534 описаний (61.0%)
# Прошла 365000 из 594534 описаний (61.4%)
# Прошла 367500 из 594534 описаний (61.8%)
# Прошла 370000 из 594534 описаний (62.2%)
# Прошла 372500 из 594534 описаний (62.7%)
# Прошла 375000 из 594534 описаний (63.1%)
# Прошла 377500 из 594534 описаний (63.5%)
# Прошла 380000 из 594534 описаний (63.9%)
# Прошла 382500 из 594534 описаний (64.3%)
# Прошла 385000 из 594534 описаний (64.8%)
# Прошла 387500 из 594534 описаний (65.2%)
# Прошла 390000 из 594534 описаний (65.6%)
# Прошла 392500 из 594534 описаний (66.0%)
# Прошла 395000 из 594534 описаний (66.4%)
# Прошла 397500 из 594534 описаний (66.9%)
# Прошла 400000 из 594534 описаний (67.3%)
# Прошла 402500 из 594534 описаний (67.7%)
# Прошла 405000 из 594534 описаний (68.1%)
# Прошла 407500 из 594534 описаний (68.5%)
# Прошла 410000 из 594534 описаний (69.0%)
# Прошла 412500 из 594534 описаний (69.4%)
# Прошла 415000 из 594534 описаний (69.8%)
# Прошла 417500 из 594534 описаний (70.2%)
# Прошла 420000 из 594534 описаний (70.6%)
# Прошла 422500 из 594534 описаний (71.1%)
# Прошла 425000 из 594534 описаний (71.5%)
# Прошла 427500 из 594534 описаний (71.9%)
# Прошла 430000 из 594534 описаний (72.3%)
# Прошла 432500 из 594534 описаний (72.7%)
# Прошла 435000 из 594534 описаний (73.2%)
# Прошла 437500 из 594534 описаний (73.6%)
# Прошла 440000 из 594534 описаний (74.0%)
# Прошла 442500 из 594534 описаний (74.4%)
# Прошла 445000 из 594534 описаний (74.8%)
# Прошла 447500 из 594534 описаний (75.3%)
# Прошла 450000 из 594534 описаний (75.7%)
# Прошла 452500 из 594534 описаний (76.1%)
# Прошла 455000 из 594534 описаний (76.5%)
# Прошла 457500 из 594534 описаний (77.0%)
# Прошла 460000 из 594534 описаний (77.4%)
# Прошла 462500 из 594534 описаний (77.8%)
# Прошла 465000 из 594534 описаний (78.2%)
# Прошла 467500 из 594534 описаний (78.6%)
# Прошла 470000 из 594534 описаний (79.1%)
# Прошла 472500 из 594534 описаний (79.5%)
# Прошла 475000 из 594534 описаний (79.9%)
# Прошла 477500 из 594534 описаний (80.3%)
# Прошла 480000 из 594534 описаний (80.7%)
# Прошла 482500 из 594534 описаний (81.2%)
# Прошла 485000 из 594534 описаний (81.6%)
# Прошла 487500 из 594534 описаний (82.0%)
# Прошла 490000 из 594534 описаний (82.4%)
# Прошла 492500 из 594534 описаний (82.8%)
# Прошла 495000 из 594534 описаний (83.3%)
# Прошла 497500 из 594534 описаний (83.7%)
# Прошла 500000 из 594534 описаний (84.1%)
# Прошла 502500 из 594534 описаний (84.5%)
# Прошла 505000 из 594534 описаний (84.9%)
# Прошла 507500 из 594534 описаний (85.4%)
# Прошла 510000 из 594534 описаний (85.8%)
# Прошла 512500 из 594534 описаний (86.2%)
# Прошла 515000 из 594534 описаний (86.6%)
# Прошла 517500 из 594534 описаний (87.0%)
# Прошла 520000 из 594534 описаний (87.5%)
# Прошла 522500 из 594534 описаний (87.9%)
# Прошла 525000 из 594534 описаний (88.3%)
# Прошла 527500 из 594534 описаний (88.7%)
# Прошла 530000 из 594534 описаний (89.1%)
# Прошла 532500 из 594534 описаний (89.6%)
# Прошла 535000 из 594534 описаний (90.0%)
# Прошла 537500 из 594534 описаний (90.4%)
# Прошла 540000 из 594534 описаний (90.8%)
# Прошла 542500 из 594534 описаний (91.2%)
# Прошла 545000 из 594534 описаний (91.7%)
# Прошла 547500 из 594534 описаний (92.1%)
# Прошла 550000 из 594534 описаний (92.5%)
# Прошла 552500 из 594534 описаний (92.9%)
# Прошла 555000 из 594534 описаний (93.4%)
# Прошла 557500 из 594534 описаний (93.8%)
# Прошла 560000 из 594534 описаний (94.2%)
# Прошла 562500 из 594534 описаний (94.6%)
# Прошла 565000 из 594534 описаний (95.0%)
# Прошла 567500 из 594534 описаний (95.5%)
# Прошла 570000 из 594534 описаний (95.9%)
# Прошла 572500 из 594534 описаний (96.3%)
# Прошла 575000 из 594534 описаний (96.7%)
# Прошла 577500 из 594534 описаний (97.1%)
# Прошла 580000 из 594534 описаний (97.6%)
# Прошла 582500 из 594534 описаний (98.0%)
# Прошла 585000 из 594534 описаний (98.4%)
# Прошла 587500 из 594534 описаний (98.8%)
# Прошла 590000 из 594534 описаний (99.2%)
# Прошла 592500 из 594534 описаний (99.7%)
# CPU times: user 42min 10s, sys: 15.1 s, total: 42min 25s
# Wall time: 42min 31s

# %%
len(sentences)
# Out:
# 1956571

# %%
sentences[1]
# Out:
# ['заместителя',
#  'заведующего',
#  'секцией',
#  'отделом',
#  'ответственность',
#  'лидерские',
#  'качества',
#  'опыт',
#  'управления',
#  'коллективом',
#  'условия',
#  'новый',
#  'современный',
#  'магазин',
#  'розничной',
#  'торговли',
#  'хозтоварами',
#  'хороший',
#  'коллектив',
#  'достойная',
#  'зарплата',
#  'премии',
#  'соц',
#  'пакет',
#  'график',
#  'работы',
#  'пн',
#  'пт',
#  'с',
#  'до',
#  'плавающий',
#  'место',
#  'работы',
#  'ул']

# %% [markdown]
# # Шаг 5. Тренируем модель
#
# * [Документация 1](https://radimrehurek.com/gensim/models/word2vec.html)
# * [Документация 2 (Google)](https://code.google.com/archive/p/word2vec/)
#
#
# <br>
#
#
# * **Architecture:** Architecture options are skip-gram (default) or continuous bag of words. We found that skip-gram was very slightly slower but produced better results.
# * **Training algorithm:** Hierarchical softmax (default) or negative sampling. For us, the default worked well.
# * **Downsampling of frequent words:** The Google documentation recommends values between .00001 and .001. For us, values closer 0.001 seemed to improve the accuracy of the final model.
# * **Word vector dimensionality:** More features result in longer runtimes, and often, but not always, result in better models. Reasonable values can be in the tens to hundreds; we used 300.
# * **Context / window size:** How many words of context should the training algorithm take into account? 10 seems to work well for hierarchical softmax (more is better, up to a point).
# * **Worker threads:** Number of parallel processes to run. This is computer-specific, but between 4 and 6 should work on most systems.
# * **Minimum word count:** This helps limit the size of the vocabulary to meaningful words. Any word that does not occur at least this many times across all documents is ignored. Reasonable values could be between 10 and 100. In this case, since each movie occurs 30 times, we set the minimum word count to 40, to avoid attaching too much importance to individual movie titles. This resulted in an overall vocabulary size of around 15,000 words. Higher values also help limit run time.

# %%
# %%time
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s',\
    level=logging.INFO)

#Укажем параметры

num_features = 300
min_word_count = 40
num_workers = 4
context = 10 
downsampling = 1e-3

from gensim.models import word2vec
print ('Обучаю word2vec')
model = word2vec.Word2Vec(sentences, workers=num_workers, 
            size=num_features, min_count = min_word_count, 
            window = context, sample = downsampling)
model.init_sims(replace=True)
model_name = '300features_40minwords_10context'
model.save(model_name)
# Out:
# 2018-09-14 13:55:49,052 : INFO : 'pattern' package not found; tag filters are not available for English
# 2018-09-14 13:55:49,059 : INFO : collecting all words and their counts
# 2018-09-14 13:55:49,060 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-09-14 13:55:49,208 : INFO : PROGRESS: at sentence #10000, processed 543285 words, keeping 35863 word types
# Обучаю word2vec
# 2018-09-14 13:55:49,367 : INFO : PROGRESS: at sentence #20000, processed 1092729 words, keeping 49798 word types
# 2018-09-14 13:55:49,517 : INFO : PROGRESS: at sentence #30000, processed 1632416 words, keeping 60370 word types
# 2018-09-14 13:55:49,676 : INFO : PROGRESS: at sentence #40000, processed 2175827 words, keeping 68796 word types
# 2018-09-14 13:55:49,825 : INFO : PROGRESS: at sentence #50000, processed 2717910 words, keeping 75913 word types
words/s, in_qsize 7, out_qsize 0
# 2018-09-14 14:02:43,683 : INFO : EPOCH 5 - PROGRESS: at 84.18% examples, 1063128 words/s, in_qsize 7, out_qsize 0
# 2018-09-14 14:02:44,686 : INFO : EPOCH 5 - PROGRESS: at 85.57% examples, 1063802 words/s, in_qsize 7, out_qsize 0
# 2018-09-14 14:02:45,691 : INFO : EPOCH 5 - PROGRESS: at 86.93% examples, 1064768 words/s, in_qsize 7, out_qsize 0
# 2018-09-14 14:02:46,696 : INFO : EPOCH 5 - PROGRESS: at 88.31% examples, 1065235 words/s, in_qsize 7, out_qsize 0
# 2018-09-14 14:02:47,704 : INFO : EPOCH 5 - PROGRESS: at 89.76% examples, 1065900 words/s, in_qsize 7, out_qsize 0
# 2018-09-14 14:02:48,707 : INFO : EPOCH 5 - PROGRESS: at 91.19% examples, 1066746 words/s, in_qsize 7, out_qsize 0
# 2018-09-14 14:02:49,710 : INFO : EPOCH 5 - PROGRESS: at 92.61% examples, 1067309 words/s, in_qsize 7, out_qsize 0
# 2018-09-14 14:02:50,711 : INFO : EPOCH 5 - PROGRESS: at 94.24% examples, 1068321 words/s, in_qsize 7, out_qsize 0
# 2018-09-14 14:02:51,721 : INFO : EPOCH 5 - PROGRESS: at 95.79% examples, 1068766 words/s, in_qsize 7, out_qsize 0
# 2018-09-14 14:02:52,727 : INFO : EPOCH 5 - PROGRESS: at 97.20% examples, 1069388 words/s, in_qsize 7, out_qsize 0
# 2018-09-14 14:02:53,730 : INFO : EPOCH 5 - PROGRESS: at 98.51% examples, 1070187 words/s, in_qsize 7, out_qsize 0
# 2018-09-14 14:02:54,737 : INFO : EPOCH 5 - PROGRESS: at 99.92% examples, 1070870 words/s, in_qsize 7, out_qsize 0
# 2018-09-14 14:02:54,770 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-09-14 14:02:54,776 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-09-14 14:02:54,781 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-09-14 14:02:54,789 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-09-14 14:02:54,790 : INFO : EPOCH - 5 : training on 96574840 raw words (81910237 effective words) took 76.5s, 1070993 effective words/s
# 2018-09-14 14:02:54,791 : INFO : training on a 482874200 raw words (409549465 effective words) took 395.1s, 1036512 effective words/s
# 2018-09-14 14:02:54,791 : INFO : precomputing L2-norms of word weight vectors
# 2018-09-14 14:02:55,268 : INFO : saving Word2Vec object under 300features_40minwords_10context, separately None
# 2018-09-14 14:02:55,269 : INFO : storing np array 'vectors' to 300features_40minwords_10context.wv.vectors.npy
# 2018-09-14 14:02:55,324 : INFO : not storing attribute vectors_norm
# 2018-09-14 14:02:55,325 : INFO : storing np array 'syn1neg' to 300features_40minwords_10context.trainables.syn1neg.npy
# 2018-09-14 14:02:55,367 : INFO : not storing attribute cum_table
# 2018-09-14 14:02:55,514 : INFO : saved 300features_40minwords_10context
# CPU times: user 26min 29s, sys: 10.7 s, total: 26min 40s
# Wall time: 7min 7s

# %% [markdown]
# # Шаг 6. Играемся с word2vec

# %%
#наименее значащее слово из списка
model.wv.doesnt_match('ответственность лидерские качества'.split())
# Out:
# /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 'качества'

# %%
model.wv.doesnt_match('офис крупная компания'.split())
# Out:
# /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 'офис'

# %%
# понимает, что слово россия не город
model.wv.doesnt_match('москва россия калуга'.split())
# Out:
# /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 'россия'

# %%
#наиболее близкие по смыслу слова
#бл%%ь, как она смогла????

model.most_similar('тула')
# Out:
# /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('киров', 0.7730791568756104),
#  ('астрахань', 0.7520081400871277),
#  ('рязань', 0.7477890253067017),
#  ('саранск', 0.7462366223335266),
#  ('смоленск', 0.7427210807800293),
#  ('мончегорск', 0.7397128343582153),
#  ('чебоксары', 0.7396755218505859),
#  ('вологда', 0.7383654713630676),
#  ('городец', 0.7333020567893982),
#  ('чита', 0.7330015897750854)]

# %%
model.most_similar('английский')
# Out:
# /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('иностранный', 0.6687490940093994),
#  ('китайский', 0.6018562316894531),
#  ('польский', 0.5978714227676392),
#  ('корейский', 0.5737009048461914),
#  ('английским', 0.5712827444076538),
#  ('англ', 0.5552904605865479),
#  ('казахский', 0.5076484680175781),
#  ('испанский', 0.5023046731948853),
#  ('русский', 0.4914351999759674),
#  ('немецкий', 0.4885626435279846)]

# %%
model.most_similar('хороший')
# Out:
# /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('отличный', 0.7360666990280151),
#  ('прекрасный', 0.5923669934272766),
#  ('высокий', 0.5381550788879395),
#  ('дружеский', 0.5331491827964783),
#  ('чудесный', 0.5301397442817688),
#  ('душевный', 0.522240161895752),
#  ('дружелюбный', 0.5203139781951904),
#  ('базовый', 0.5194989442825317),
#  ('сильный', 0.5179193615913391),
#  ('приятный', 0.5139368176460266)]

# %%
model.most_similar('образование')
# Out:
# /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('образованиеопыт', 0.5119481086730957),
#  ('образованиеусловия', 0.458920419216156),
#  ('образования', 0.3992411196231842),
#  ('аналогичный', 0.39759761095046997),
#  ('предпочтительно', 0.3966981768608093),
#  ('желательно', 0.39301443099975586),
#  ('релевантный', 0.3916599750518799),
#  ('микробиология', 0.3890746235847473),
#  ('опыт', 0.3890298306941986),
#  ('аспирантура', 0.3886414170265198)]

# %%
model.most_similar('настроение')
# Out:
# /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('зрение', 0.628744900226593),
#  ('произношение', 0.5705733299255371),
#  ('дарить', 0.5688424110412598),
#  ('позитив', 0.4668731093406677),
#  ('ориентирование', 0.4567759335041046),
#  ('впечатление', 0.44994938373565674),
#  ('воображение', 0.44943249225616455),
#  ('начальство', 0.4452277421951294),
#  ('понедельникам', 0.4411506950855255),
#  ('юмора', 0.4282305836677551)]

# %%
from gensim.models import Word2Vec
model = Word2Vec.load("300features_40minwords_10context")
# Out:
# 2018-09-14 14:25:18,931 : INFO : loading Word2Vec object from 300features_40minwords_10context
# 2018-09-14 14:25:19,043 : INFO : loading wv recursively from 300features_40minwords_10context.wv.* with mmap=None
# 2018-09-14 14:25:19,044 : INFO : loading vectors from 300features_40minwords_10context.wv.vectors.npy with mmap=None
# 2018-09-14 14:25:19,104 : INFO : setting ignored attribute vectors_norm to None
# 2018-09-14 14:25:19,105 : INFO : loading vocabulary recursively from 300features_40minwords_10context.vocabulary.* with mmap=None
# 2018-09-14 14:25:19,105 : INFO : loading trainables recursively from 300features_40minwords_10context.trainables.* with mmap=None
# 2018-09-14 14:25:19,106 : INFO : loading syn1neg from 300features_40minwords_10context.trainables.syn1neg.npy with mmap=None
# 2018-09-14 14:25:19,182 : INFO : setting ignored attribute cum_table to None
# 2018-09-14 14:25:19,182 : INFO : loaded 300features_40minwords_10context

# %%
model.most_similar('настроение')
# Out:
# /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# 2018-09-14 14:25:36,552 : INFO : precomputing L2-norms of word weight vectors
# /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('зрение', 0.628744900226593),
#  ('произношение', 0.5705733299255371),
#  ('дарить', 0.5688424110412598),
#  ('позитив', 0.4668731093406677),
#  ('ориентирование', 0.4567759335041046),
#  ('впечатление', 0.4499494433403015),
#  ('воображение', 0.44943249225616455),
#  ('начальство', 0.4452277421951294),
#  ('понедельникам', 0.4411506950855255),
#  ('юмора', 0.4282305836677551)]

# %%
type(model.syn0_lockf)
# Out:
# /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `syn0_lockf` (Attribute will be removed in 4.0.0, use self.trainables.vectors_lockf instead).
#   """Entry point for launching an IPython kernel.
# numpy.ndarray

# %%
model.most_similar('россия')
# Out:
# /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('эстония', 0.6653217077255249),
#  ('украина', 0.6576091051101685),
#  ('бельгия', 0.6269100904464722),
#  ('италия', 0.62611985206604),
#  ('грузия', 0.6243079304695129),
#  ('финляндия', 0.6174194812774658),
#  ('белоруссия', 0.6120906472206116),
#  ('азия', 0.6019402742385864),
#  ('франция', 0.6013780832290649),
#  ('испания', 0.598772406578064)]

# %%
model.syn0_lockf.shape
# Out:
# /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `syn0_lockf` (Attribute will be removed in 4.0.0, use self.trainables.vectors_lockf instead).
#   """Entry point for launching an IPython kernel.
# (52725,)

# %%
model['россия'].shape
# Out:
# /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# (300,)

# %% [markdown]
# # Шаг 7. Делаем для каждого описания свой вектор

# %%
import numpy as np

def makeFeatureVec (words, model, num_features):
    featureVec = np.zeros((num_features,), dtype='float32')
    nwords = 0.
    index2word_set = set(model.wv.index2word)
    for word in words:
        if word in index2word_set:
            nwords = nwords + 1.
            featureVec = np.add(featureVec,model[word])
    featureVec = np.divide(featureVec,nwords)
    return featureVec

# %%
def getAvgFeatureVecs(descriptions, model, num_features):
    counter = 0
    vacFeatureVecs = np.zeros((len(descriptions), num_features),dtype='float32')
    for description in descriptions:
        if counter%10000 == 0:
            print('Описание {} из {} обработано...'.format(counter, len(descriptions)))
        vacFeatureVecs[counter] = makeFeatureVec(description, model, num_features)
        counter = counter + 1
    return vacFeatureVecs

# %% [markdown]
# Вызываем функцию getAvgFeatureVecs для каждого описания

# %%
# %%time
print('=========Делаем вектора для тренировочного датасета=========')
clean_train_vacs = []
i = 0
for vacancy in train_df['description']:
    if (i+1)%20000 == 0:
        print('Делаю набор слов для {} описания из {}'.format(i+1, train_df['description'].size))        
    clean_train_vacs.append(vac_to_wordlist(vacancy, remove_stopwords=True))
    i += 1

trainDataVecs = getAvgFeatureVecs(clean_train_vacs, model, num_features)
print('============Делаем вектора для тестового датасета============')
clean_test_vacs = []
i = 0
for vacancy in test_df['description']:
    if (i+1)%20000 == 0:
        print('Делаю набор слов для {} описания из {}'.format(i+1, test_df['description'].size))      
    clean_test_vacs.append(vac_to_wordlist(vacancy, remove_stopwords=True))
    i += 1    
testDataVecs = getAvgFeatureVecs(clean_test_vacs, model, num_features)
# Out:
# Делаем вектора для тренировочного датасета
# Делаю 19999 из 200000
# Делаю 39999 из 200000
# Делаю 59999 из 200000
# Делаю 79999 из 200000
# Делаю 99999 из 200000
# Делаю 119999 из 200000
# Делаю 139999 из 200000
# Делаю 159999 из 200000
# Делаю 179999 из 200000
# Делаю 199999 из 200000
# Описание 0 из 200000 обработано...
# /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   # Remove the CWD from sys.path while we load stuff.
# Описание 10000 из 200000 обработано...
# Описание 20000 из 200000 обработано...
# Описание 30000 из 200000 обработано...
# /Users/aleksandrpolakov/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in true_divide
#   # This is added back by InteractiveShellApp.init_path()
# Описание 40000 из 200000 обработано...
# Описание 50000 из 200000 обработано...
# Описание 60000 из 200000 обработано...
# Описание 70000 из 200000 обработано...
# Описание 80000 из 200000 обработано...
# Описание 90000 из 200000 обработано...
# Описание 100000 из 200000 обработано...
# Описание 110000 из 200000 обработано...
# Описание 120000 из 200000 обработано...
# Описание 130000 из 200000 обработано...
# Описание 140000 из 200000 обработано...
# Описание 150000 из 200000 обработано...
# Описание 160000 из 200000 обработано...
# Описание 170000 из 200000 обработано...
# Описание 180000 из 200000 обработано...
# Описание 190000 из 200000 обработано...
# Делаем вектора для тестового датасета
# Делаю 19999 из 170179
# Делаю 39999 из 170179
# Делаю 59999 из 170179
# Делаю 79999 из 170179
# Делаю 99999 из 170179
# Делаю 119999 из 170179
# Делаю 139999 из 170179
# Делаю 159999 из 170179
# Описание 0 из 170179 обработано...
# Описание 10000 из 170179 обработано...
# Описание 20000 из 170179 обработано...
# Описание 30000 из 170179 обработано...
# Описание 40000 из 170179 обработано...
# Описание 50000 из 170179 обработано...
# Описание 60000 из 170179 обработано...
# Описание 70000 из 170179 обработано...
# Описание 80000 из 170179 обработано...
# Описание 90000 из 170179 обработано...
# Описание 100000 из 170179 обработано...
# Описание 110000 из 170179 обработано...
# Описание 120000 из 170179 обработано...
# Описание 130000 из 170179 обработано...
# Описание 140000 из 170179 обработано...
# Описание 150000 из 170179 обработано...
# Описание 160000 из 170179 обработано...
# Описание 170000 из 170179 обработано...
# CPU times: user 35min 49s, sys: 19.7 s, total: 36min 9s
# Wall time: 36min 14s

# %%
testDataVecs[40000:].shape
# Out:
# (130179, 300)

# %%
trainDataVecs
# Out:
# array([[ 0.01022952,  0.00219718, -0.00197375, ..., -0.0077006 ,
#          0.00371153,  0.01921921],
#        [ 0.02177511, -0.00804649, -0.00751581, ...,  0.01357641,
#         -0.04320358,  0.02277128],
#        [ 0.00184524,  0.00429932,  0.00345538, ..., -0.00247294,
#         -0.01102962, -0.00936679],
#        ...,
#        [-0.00173076,  0.00233004,  0.01474884, ...,  0.01413206,
#         -0.01448921,  0.00074065],
#        [-0.00715773,  0.01531241,  0.00562211, ...,  0.00131948,
#         -0.01723835,  0.01184722],
#        [ 0.00730153, -0.0042074 ,  0.00426561, ..., -0.02178605,
#         -0.01282327,  0.02013533]], dtype=float32)

# %% [markdown]
# # Шаг 8. Random Forest

# %%
# %%time
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(n_estimators = 100)
print ('Обучаем Random Forest на размеченных данных...')
# прибили все значения, которые NaN (сообщение об ошибке вылетало в прошлом пункте) и поставили вместо них нули
trainDataVecs[np.isnan(trainDataVecs)]=0 
forest = forest.fit(trainDataVecs, train_df['target'])
result = forest.predict(testDataVecs)
output = pd.DataFrame( data={'id':test_df['id'], 'target':result} )
output.to_csv( "Random_Forest_Word2Vec_Vector_Averaging.csv", sep=',', encoding='utf-8',index=False )
# Out:
# Обучаем Random Forest на размеченных данных...
# CPU times: user 7min 58s, sys: 1.57 s, total: 7min 59s
# Wall time: 7min 56s

# %%
#чисто из любопытства посмотреть
output.head()
# Out:
#        id  target
# 0  200000       1
# 1  200001       1
# 2  200002       1
# 3  200003       1
# 4  200004       0
